# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup 
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import plotly.express as px
import openai
import os
import time

# %%
openai.api_key ="secret :-)"

def chatgpt(message):
    time.sleep(0.1)
    completion = openai.chat.completions.create(model="gpt-4o-mini",messages=[{"role": "user","content": message,},],)
    print(completion.choices[0].message.content)
    return completion.choices[0].message.content

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4o-mini")

with open("data/plot_summaries.txt", "r",encoding="utf-8") as file:
    text = file.read()

tokens = encoding.encode(text)
num_tokens = len(tokens)

print(f"Number of tokens in the document: {num_tokens}")
# Out:
# Number of tokens in the document: 16544268

# %%
price_dataset = (0.15*16544268)/1000000
price_dataset
# Out:
# 2.4816401999999997

# %%
folder = "generated/"
df_movies=pd.read_csv(folder + "cleaned_data.csv",index_col = 'Wikipedia movie ID')
df_movies.head(10)
# Out:
#                                                            Movie name  \
# Wikipedia movie ID
# 975900                                                 Ghosts of Mars
# 3196793             Getting Away with Murder: The JonBenét Ramsey ...
# 28463795                                                  Brun bitter
# 9363483                                              White Of The Eye
# 261236                                              A Woman in Flames
# 13696889                                                The Gangsters
# 18998739                                    The Sorcerer's Apprentice
# 10408933                                     Alexander's Ragtime Band
# 9997961                                                Contigo y aquí
# 2345652                                              City of the Dead
#
#                     Movie release month  Movie release year  \
# Wikipedia movie ID
# 975900                              8.0              2001.0
# ...

# %%
#df_movies['Theme'] = df_movies['Summary'].apply(lambda x: chatgpt(pre + x) if pd.notna(summary) else np.nan)
pre = "Label the movie's theme with a single word based on its plot : "
df_test['Theme'] = None
df_test = df_movies.sample(10)
df_test['Theme'] = df_test['Summary'].apply(lambda x: chatgpt(pre + x) if pd.notna(x) else np.nan)
# Out:
# Transformation
# Heritage
# Chaos
# Revenge

# %%
df_test.dtypes
# Out:
# Movie name                   object
# Movie release month         float64
# Movie release year          float64
# Movie release date           object
# Movie box office revenue    float64
# Movie runtime               float64
# Movie languages              object
# Movie countries              object
# Movie genres                 object
# Summary                      object
# Sentiment                    object
# Compound Score              float64
# Theme                        object
# dtype: object

# %%
df_test.head(10)
# Out:
#                                          Movie name  Movie release month  \
# Wikipedia movie ID
# 31935306                        The Man of the Year                  NaN
# 31093048                                      Swing                  NaN
# 31028206                       Dos Tipos de Cuidado                  NaN
# 6614056                                The Overture                  NaN
# 4658336              Depeche Mode: The Videos 86>98                  NaN
# 32228998                                     Flames                  NaN
# 3620996             Rikidozan: A Hero Extraordinary                  NaN
# 32044375                                   Delivery                  NaN
# 4401133                                 Smiley Face                  1.0
# 9678161                         Maanbumigu Maanavan                  NaN
#
#                     Movie release year Movie release date  \
# Wikipedia movie ID
# 31935306                        2003.0                NaN
# ...
