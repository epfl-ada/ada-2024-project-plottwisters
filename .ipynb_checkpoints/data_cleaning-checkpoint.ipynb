# %% [markdown]
# # 1. IMPORTS

# %%
import pandas as pd
import numpy as np
import re  # This imports the regular expressions module
# %matplotlib inline
import matplotlib.pyplot as plt

DATA_FOLDER = 'Data/'

CHARACTER_METADATA_DATASET = DATA_FOLDER+"character.metadata.tsv"
MOVIE_METADATA_DATASET = DATA_FOLDER+"movie.metadata.tsv"

# %%
column_names_character = [
    'Wikipedia movie ID',
    'Freebase movie ID',
    'Movie release date',
    'Character name',
    'Actor date of birth',
    'Actor gender',
    'Actor height (in meters)',
    'Actor ethnicity (Freebase ID)',
    'Actor name',
    'Actor age at movie release',
    'Freebase character/actor map ID',
    'Freebase character ID',
    'Freebase actor ID'
]

column_names_movie = [
    'Wikipedia movie ID',
    'Freebase movie ID',
    'Movie name',
    'Movie release date',
    'Movie box office revenue',
    'Movie runtime',
    'Movie languages',
    'Movie countries',
    'Movie genres'
]
df_character=pd.read_csv(CHARACTER_METADATA_DATASET, sep='\t', names = column_names_character)
df_movie=pd.read_csv(MOVIE_METADATA_DATASET, sep='\t', names = column_names_movie)

# %%
row_with_id_3333 = df_movie[df_movie['Wikipedia movie ID'] == 3333]
row_with_id_3333
# Out:
#       Wikipedia movie ID Freebase movie ID             Movie name  \
# 2634                3333          /m/0151l  The Birth of a Nation
#
#      Movie release date  Movie box office revenue  Movie runtime  \
# 2634               1915                50000000.0          190.0
#
#                                         Movie languages  \
# 2634  {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
#
#                                 Movie countries  \
# 2634  {"/m/09c7w0": "United States of America"}
#
#                                            Movie genres
# 2634  {"/m/06ppq": "Silent film", "/m/0219x_": "Indi...

# %%
#Columns we will use for our project
df = df_movie[['Wikipedia movie ID','Movie release date','Movie box office revenue','Movie runtime','Movie languages','Movie countries','Movie genres']] #and themes to add
df.set_index('Wikipedia movie ID', inplace=True)

df
# Out:
#                    Movie release date  Movie box office revenue  \
# Wikipedia movie ID
# 975900                     2001-08-24                14010832.0
# 3196793                    2000-02-16                       NaN
# 28463795                         1988                       NaN
# 9363483                          1987                       NaN
# 261236                           1983                       NaN
# ...                               ...                       ...
# 35228177                   2011-03-19                       NaN
# 34980460                   2011-01-21                       NaN
# 9971909                    1972-09-22                       NaN
# 913762                     1992-05-21                       NaN
# 12476867                         2002                       NaN
#
#                     Movie runtime                     Movie languages  \
# Wikipedia movie ID
# 975900                       98.0  {"/m/02h40lc": "English Language"}
# 3196793                      95.0  {"/m/02h40lc": "English Language"}
# 28463795                     83.0  {"/m/05f_3": "Norwegian Language"}
# 9363483                     110.0  {"/m/02h40lc": "English Language"}
# 261236                      106.0   {"/m/04306rv": "German Language"}
# ...                           ...                                 ...
# 35228177                    120.0  {"/m/02h40lc": "English Language"}
# 34980460                     96.0  {"/m/02h40lc": "English Language"}
# 9971909                      66.0  {"/m/02h40lc": "English Language"}
# 913762                      150.0   {"/m/03_9r": "Japanese Language"}
# 12476867                     86.0  {"/m/02h40lc": "English Language"}
#
#                                                       Movie countries  \
# Wikipedia movie ID
# 975900                      {"/m/09c7w0": "United States of America"}
# 3196793                     {"/m/09c7w0": "United States of America"}
# 28463795                                       {"/m/05b4w": "Norway"}
# 9363483                                {"/m/07ssc": "United Kingdom"}
# 261236                                        {"/m/0345h": "Germany"}
# ...                                                               ...
# 35228177                    {"/m/09c7w0": "United States of America"}
# 34980460            {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 9971909                     {"/m/09c7w0": "United States of America"}
# 913762                                          {"/m/03_3d": "Japan"}
# 12476867                                      {"/m/0d060g": "Canada"}
#
#                                                          Movie genres
# Wikipedia movie ID
# 975900              {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3196793             {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 28463795            {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 9363483             {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 261236                                        {"/m/07s9rl0": "Drama"}
# ...                                                               ...
# 35228177                                      {"/m/07s9rl0": "Drama"}
# 34980460            {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 9971909                  {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
# 913762              {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 12476867            {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
# [81741 rows x 6 columns]

# %%
is_unique = df.index.is_unique
print("Is the index unique?", is_unique)
# Out:
# Is the index unique? True

# %%
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81741 entries, 975900 to 12476867
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Movie release date        74839 non-null  object
#  1   Movie box office revenue  8401 non-null   float64
#  2   Movie runtime             61291 non-null  float64
#  3   Movie languages           81741 non-null  object
#  4   Movie countries           81741 non-null  object
#  5   Movie genres              81741 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 6.4+ MB

# %% [markdown]
# # 2. Data handling

# %% [markdown]
# ## Clean dates

# %%
#Problem : We don't have the day and month for many movies (+- half) and some don't have a date at all.
#Solution : Create a "year" column and "day-month" column with nan values when it's missing. 
# Extract the first 4 characters, handling NaNs
df_treated = df.copy()
df_treated['Movie release year'] = df_treated['Movie release date'].str[:4].astype('Int32') #7k nans


cols = list(df_treated.columns)
cols.insert(1, cols.pop(cols.index('Movie release year')))
df_treated = df_treated[cols]

df_treated['Movie release date'] = pd.to_datetime(df_treated['Movie release date'], errors='coerce') #42k nans
df_treated['Movie release month'] = df_treated['Movie release date'].dt.strftime('%m').astype('Int32')

print(df_treated['Movie release date'].isna().sum())
print(df_treated['Movie release year'].isna().sum())
print(df_treated['Movie release month'].isna().sum())

cols = list(df_treated.columns)
cols.insert(1, cols.pop(cols.index('Movie release month')))
df_treated = df_treated[cols]
df_treated.head(20)
# Out:
# 42369
# 6902
# 42369
#                    Movie release date  Movie release month  \
# Wikipedia movie ID
# 975900                     2001-08-24                    8
# 3196793                    2000-02-16                    2
# 28463795                          NaT                 <NA>
# 9363483                           NaT                 <NA>
# 261236                            NaT                 <NA>
# 13696889                   1913-05-29                    5
# 18998739                          NaT                 <NA>
# 10408933                   1938-08-16                    8
# 9997961                           NaT                 <NA>
# 2345652                           NaT                 <NA>
# 175026                            NaT                 <NA>
# 24229100                          NaT                 <NA>
# 6631279                    1997-04-04                    4
# 171005                     1989-11-08                   11
# 18296435                          NaT                 <NA>
# 11250635                          NaT                 <NA>
# 30388930                          NaT                 <NA>
# 77856                      1964-08-27                    8
# 32456683                          NaT                 <NA>
# 33420460                          NaT                 <NA>
#
#                     Movie release year  Movie box office revenue  \
# Wikipedia movie ID
# 975900                            2001                14010832.0
# 3196793                           2000                       NaN
# 28463795                          1988                       NaN
# 9363483                           1987                       NaN
# 261236                            1983                       NaN
# 13696889                          1913                       NaN
# 18998739                          2002                       NaN
# 10408933                          1938                 3600000.0
# 9997961                           1974                       NaN
# 2345652                           1960                       NaN
# 175026                            1930                       NaN
# 24229100                          1974                       NaN
# 6631279                           1997                       NaN
# 171005                            1989                10161099.0
# 18296435                          1986                       NaN
# 11250635                          <NA>                       NaN
# 30388930                          1984                       NaN
# 77856                             1964               102272727.0
# 32456683                          1967                       NaN
# 33420460                          1992                       NaN
#
#                     Movie runtime  \
# Wikipedia movie ID
# 975900                       98.0
# 3196793                      95.0
# 28463795                     83.0
# 9363483                     110.0
# 261236                      106.0
# 13696889                     35.0
# 18998739                     86.0
# 10408933                    106.0
# 9997961                       NaN
# 2345652                      76.0
# 175026                       86.0
# 24229100                     89.0
# 6631279                      93.0
# 171005                      137.0
# 18296435                      NaN
# 11250635                      NaN
# 30388930                     99.0
# 77856                       139.0
# 32456683                    108.0
# 33420460                     97.0
#
#                                                       Movie languages  \
# Wikipedia movie ID
# 975900                             {"/m/02h40lc": "English Language"}
# 3196793                            {"/m/02h40lc": "English Language"}
# 28463795                           {"/m/05f_3": "Norwegian Language"}
# 9363483                            {"/m/02h40lc": "English Language"}
# 261236                              {"/m/04306rv": "German Language"}
# 13696889            {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 18998739                           {"/m/02h40lc": "English Language"}
# 10408933                           {"/m/02h40lc": "English Language"}
# 9997961                              {"/m/06nm1": "Spanish Language"}
# 2345652                            {"/m/02h40lc": "English Language"}
# 175026                             {"/m/02h40lc": "English Language"}
# 24229100                            {"/m/03_9r": "Japanese Language"}
# 6631279                            {"/m/02h40lc": "English Language"}
# 171005                             {"/m/02h40lc": "English Language"}
# 18296435                           {"/m/02hwyss": "Turkish Language"}
# 11250635                           {"/m/02h40lc": "English Language"}
# 30388930                                                           {}
# 77856                              {"/m/02h40lc": "English Language"}
# 32456683                            {"/m/04306rv": "German Language"}
# 33420460                           {"/m/02h40lc": "English Language"}
#
#                                                Movie countries  \
# Wikipedia movie ID
# 975900               {"/m/09c7w0": "United States of America"}
# 3196793              {"/m/09c7w0": "United States of America"}
# 28463795                                {"/m/05b4w": "Norway"}
# 9363483                         {"/m/07ssc": "United Kingdom"}
# 261236                                 {"/m/0345h": "Germany"}
# 13696889             {"/m/09c7w0": "United States of America"}
# 18998739                          {"/m/0hzlz": "South Africa"}
# 10408933             {"/m/09c7w0": "United States of America"}
# 9997961                               {"/m/0jgd": "Argentina"}
# 2345652                         {"/m/07ssc": "United Kingdom"}
# 175026               {"/m/09c7w0": "United States of America"}
# 24229100                                 {"/m/03_3d": "Japan"}
# 6631279              {"/m/09c7w0": "United States of America"}
# 171005                          {"/m/07ssc": "United Kingdom"}
# 18296435                               {"/m/01znc_": "Turkey"}
# 11250635             {"/m/09c7w0": "United States of America"}
# 30388930                                                    {}
# 77856                {"/m/09c7w0": "United States of America"}
# 32456683            {"/m/03f2w": "German Democratic Republic"}
# 33420460             {"/m/09c7w0": "United States of America"}
#
#                                                          Movie genres
# Wikipedia movie ID
# 975900              {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3196793             {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 28463795            {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 9363483             {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 261236                                        {"/m/07s9rl0": "Drama"}
# 13696889            {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
# 18998739            {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 10408933            {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...
# 9997961             {"/m/04t36": "Musical", "/m/07s9rl0": "Drama",...
# 2345652             {"/m/03npn": "Horror", "/m/0fdjb": "Supernatur...
# 175026              {"/m/07s9rl0": "Drama", "/m/01g6gs": "Black-an...
# 24229100            {"/m/0lsxr": "Crime Fiction", "/m/01jfsb": "Th...
# 6631279             {"/m/06cvj": "Romantic comedy", "/m/0hj3n0w": ...
# 171005              {"/m/04xvh5": "Costume drama", "/m/082gq": "Wa...
# 18296435                                       {"/m/01z4y": "Comedy"}
# 11250635            {"/m/06n90": "Science Fiction", "/m/03k9fj": "...
# 30388930                                      {"/m/07s9rl0": "Drama"}
# 77856               {"/m/0hj3myq": "Children's/Family", "/m/04t36"...
# 32456683                                                           {}
# 33420460                                      {"/m/07s9rl0": "Drama"}

# %%
df_treated.dtypes
# Out:
# Movie release date          datetime64[ns]
# Movie release month                  Int32
# Movie release year                   Int32
# Movie box office revenue           float64
# Movie runtime                      float64
# Movie languages                     object
# Movie countries                     object
# Movie genres                        object
# dtype: object

# %%
df_treated['Movie release year'].value_counts().sort_index()
#one movie during the Middle Ages !!
df_treated = df_treated[df_treated['Movie release year'] != 1010]

# %%
plt.figure(figsize=(10, 6))
df_treated['Movie release year'].value_counts().sort_index().plot(kind='line')
plt.xlabel("Movie Release Year")
plt.ylabel("Number of Movies")
plt.title("Number of Movies by Release Year")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Box office

# %%
df_plot = df_treated.dropna(subset=['Movie release year', 'Movie box office revenue'])
average_revenue_per_year = df_plot.groupby('Movie release year')['Movie box office revenue'].mean()
plt.figure(figsize=(10, 6))
plt.plot(average_revenue_per_year.index, average_revenue_per_year.values)
plt.xlabel("Movie Release Year")
plt.ylabel("Average Box Office Revenue")
plt.title("Average Box Office Revenue by Movie Release Year")
plt.show()

# %%
#Problem : one cannot compare two box office values between each other as there is inflation over time and the box office revenues were measured in different years.
#Solution : adjust the (USD) box office revenue by converting the box office revenue to 2024 with the inflation rates. 
inflation_data = {
    1914: 1.3, 1915: 0.9, 1916: 7.7, 1917: 17.8, 1918: 17.3, 
    1919: 15.2, 1920: 15.6, 1921: -10.9, 1922: -6.2, 1923: 1.8, 
    1924: 0.4, 1925: 2.4, 1926: 0.9, 1927: -1.9, 1928: -1.2, 
    1929: 0.0, 1930: -2.7, 1931: -8.9, 1932: -10.3, 1933: -5.2, 
    1934: 3.5, 1935: 2.6, 1936: 1.0, 1937: 3.7, 1938: -2.0, 
    1939: -1.3, 1940: 0.7, 1941: 5.1, 1942: 10.9, 1943: 6.0, 
    1944: 1.6, 1945: 2.3, 1946: 8.5, 1947: 14.4, 1948: 7.7, 
    1949: -1.0, 1950: 1.1, 1951: 7.9, 1952: 2.3, 1953: 0.8, 
    1954: 0.3, 1955: -0.3, 1956: 1.5, 1957: 3.3, 1958: 2.7, 
    1959: 1.08, 1960: 1.5, 1961: 1.1, 1962: 1.2, 1963: 1.2, 
    1964: 1.3, 1965: 1.6, 1966: 3.0, 1967: 2.8, 1968: 4.3, 
    1969: 5.5, 1970: 5.8, 1971: 4.3, 1972: 3.3, 1973: 6.2, 
    1974: 11.1, 1975: 9.1, 1976: 5.7, 1977: 6.5, 1978: 7.6, 
    1979: 11.3, 1980: 13.5, 1981: 10.3, 1982: 6.1, 1983: 3.2, 
    1984: 4.3, 1985: 3.5, 1986: 1.9, 1987: 3.7, 1988: 4.1, 
    1989: 4.8, 1990: 5.4, 1991: 4.2, 1992: 3.0, 1993: 3.0, 
    1994: 2.6, 1995: 2.8, 1996: 2.9, 1997: 2.3, 1998: 1.6, 
    1999: 2.2, 2000: 3.4, 2001: 2.8, 2002: 1.6, 2003: 2.3, 
    2004: 2.7, 2005: 3.4, 2006: 3.2, 2007: 2.9, 2008: 3.8, 
    2009: -0.4, 2010: 1.6, 2011: 3.2, 2012: 2.1, 2013: 1.5, 
    2014: 1.6, 2015: 0.1, 2016: 1.3, 2017: 2.1, 2018: 2.4, 
    2019: 1.8, 2020: 1.2, 2021: 4.7, 2022: 8.0, 2023: 4.1, 2024: 3.2
}

#source : minesota website

def adjust_for_inflation(year, amount, inflation_data):
    """
    Adjusts the given amount from the provided year to 2024 based on annual inflation rates.

    Parameters:
    year (int): The starting year.
    amount (float): The amount to be adjusted.
    inflation_data (dict): A dictionary with years as keys and inflation rates as values.

    Returns:
    float: The inflation-adjusted amount for 2024.
    """
    # Initialize the adjusted amount
    adjusted_value = amount
    
    # Loop through each year from the given year to 2024
    for y in range(year, 2024):
        if y in inflation_data:
            inflation_rate = inflation_data[y]
            # Adjust for inflation for each year
            adjusted_value *= (1 + inflation_rate / 100)
        else:
            print(f"Warning: No inflation data available for year {y}. Assuming 0% inflation.")
    
    return adjusted_value


for i in range(len(df_treated)):
    # Check if both the release date and box office revenue are not NaN
    if pd.notna(df_treated.iloc[i]['Movie release year']) and pd.notna(df_treated.iloc[i]['Movie box office revenue']):
        # Extract the year from the release date
        release_year = df_treated['Movie release year'].iloc[i]
        
        # Adjust the box office revenue for inflation
        adjusted_revenue = adjust_for_inflation(release_year, df_treated.iloc[i]['Movie box office revenue'], inflation_data)
        
        # Update the DataFrame with the adjusted revenue using iloc
        df_treated.iloc[i, df_treated.columns.get_loc('Movie box office revenue')] = adjusted_revenue
 
df_treated.head(10)
# Out:
# Warning: No inflation data available for year 1897. Assuming 0% inflation.
# Warning: No inflation data available for year 1898. Assuming 0% inflation.
# Warning: No inflation data available for year 1899. Assuming 0% inflation.
# Warning: No inflation data available for year 1900. Assuming 0% inflation.
# Warning: No inflation data available for year 1901. Assuming 0% inflation.
# Warning: No inflation data available for year 1902. Assuming 0% inflation.
# Warning: No inflation data available for year 1903. Assuming 0% inflation.
# Warning: No inflation data available for year 1904. Assuming 0% inflation.
# Warning: No inflation data available for year 1905. Assuming 0% inflation.
# Warning: No inflation data available for year 1906. Assuming 0% inflation.
# Warning: No inflation data available for year 1907. Assuming 0% inflation.
# Warning: No inflation data available for year 1908. Assuming 0% inflation.
# Warning: No inflation data available for year 1909. Assuming 0% inflation.
# Warning: No inflation data available for year 1910. Assuming 0% inflation.
# Warning: No inflation data available for year 1911. Assuming 0% inflation.
# Warning: No inflation data available for year 1912. Assuming 0% inflation.
# Warning: No inflation data available for year 1913. Assuming 0% inflation.
#                    Movie release date  Movie release month  \
# Wikipedia movie ID
# 975900                     2001-08-24                    8
# 3196793                    2000-02-16                    2
# 28463795                          NaT                 <NA>
# 9363483                           NaT                 <NA>
# 261236                            NaT                 <NA>
# 13696889                   1913-05-29                    5
# 18998739                          NaT                 <NA>
# 10408933                   1938-08-16                    8
# 9997961                           NaT                 <NA>
# 2345652                           NaT                 <NA>
#
#                     Movie release year  Movie box office revenue  \
# Wikipedia movie ID
# 975900                            2001              2.477118e+07
# 3196793                           2000                       NaN
# 28463795                          1988                       NaN
# 9363483                           1987                       NaN
# 261236                            1983                       NaN
# 13696889                          1913                       NaN
# 18998739                          2002                       NaN
# 10408933                          1938              7.619573e+07
# 9997961                           1974                       NaN
# 2345652                           1960                       NaN
#
#                     Movie runtime  \
# Wikipedia movie ID
# 975900                       98.0
# 3196793                      95.0
# 28463795                     83.0
# 9363483                     110.0
# 261236                      106.0
# 13696889                     35.0
# 18998739                     86.0
# 10408933                    106.0
# 9997961                       NaN
# 2345652                      76.0
#
#                                                       Movie languages  \
# Wikipedia movie ID
# 975900                             {"/m/02h40lc": "English Language"}
# 3196793                            {"/m/02h40lc": "English Language"}
# 28463795                           {"/m/05f_3": "Norwegian Language"}
# 9363483                            {"/m/02h40lc": "English Language"}
# 261236                              {"/m/04306rv": "German Language"}
# 13696889            {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 18998739                           {"/m/02h40lc": "English Language"}
# 10408933                           {"/m/02h40lc": "English Language"}
# 9997961                              {"/m/06nm1": "Spanish Language"}
# 2345652                            {"/m/02h40lc": "English Language"}
#
#                                               Movie countries  \
# Wikipedia movie ID
# 975900              {"/m/09c7w0": "United States of America"}
# 3196793             {"/m/09c7w0": "United States of America"}
# 28463795                               {"/m/05b4w": "Norway"}
# 9363483                        {"/m/07ssc": "United Kingdom"}
# 261236                                {"/m/0345h": "Germany"}
# 13696889            {"/m/09c7w0": "United States of America"}
# 18998739                         {"/m/0hzlz": "South Africa"}
# 10408933            {"/m/09c7w0": "United States of America"}
# 9997961                              {"/m/0jgd": "Argentina"}
# 2345652                        {"/m/07ssc": "United Kingdom"}
#
#                                                          Movie genres
# Wikipedia movie ID
# 975900              {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 3196793             {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 28463795            {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 9363483             {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 261236                                        {"/m/07s9rl0": "Drama"}
# 13696889            {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
# 18998739            {"/m/0hqxf": "Family Film", "/m/01hmnh": "Fant...
# 10408933            {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...
# 9997961             {"/m/04t36": "Musical", "/m/07s9rl0": "Drama",...
# 2345652             {"/m/03npn": "Horror", "/m/0fdjb": "Supernatur...

# %%
filtered_df = df_treated[(df_treated['Movie box office revenue'] >= 1.517601e+08) & (df_treated['Movie release year'] == 1915)]
filtered_df
# Out:
#                    Movie release date  Movie release month  \
# Wikipedia movie ID
# 3333                              NaT                 <NA>
#
#                     Movie release year  Movie box office revenue  \
# Wikipedia movie ID
# 3333                              1915              1.517601e+09
#
#                     Movie runtime  \
# Wikipedia movie ID
# 3333                        190.0
#
#                                                       Movie languages  \
# Wikipedia movie ID
# 3333                {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
#
#                                               Movie countries  \
# Wikipedia movie ID
# 3333                {"/m/09c7w0": "United States of America"}
#
#                                                          Movie genres
# Wikipedia movie ID
# 3333                {"/m/06ppq": "Silent film", "/m/0219x_": "Indi...

# %%
df_plot = df_treated.dropna(subset=['Movie release year', 'Movie box office revenue'])
average_revenue_stats = df_plot.groupby('Movie release year')['Movie box office revenue'].agg(['mean', 'count'])
average_revenue_stats.columns = ['Average Revenue', 'Sample Count']
average_revenue_stats.head(20)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot average revenue on the first y-axis
ax1.set_xlabel("Movie Release Year")
ax1.set_ylabel("Average Box Office Revenue", color="tab:blue")
ax1.plot(average_revenue_stats.index, average_revenue_stats['Average Revenue'], color="tab:blue", label="Average Revenue")
ax1.tick_params(axis='y', labelcolor="tab:blue")
ax1.grid(True)

# Create a second y-axis for the sample count
ax2 = ax1.twinx()
ax2.set_ylabel("Sample Count", color="tab:orange")
ax2.bar(average_revenue_stats.index, average_revenue_stats['Sample Count'], color="tab:orange", alpha=0.3, label="Sample Count")
ax2.tick_params(axis='y', labelcolor="tab:orange")

# Title and legends
fig.suptitle("Average Box Office Revenue and Sample Count by Movie Release Year")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Languages

# %%
print(df_treated['Movie languages'].isna().sum())

# %%
def cleaner(value):
    # Remove `{` and `}`
    value = re.sub(r'[{}]', '', value)
    
    # Extract values after ':' that are in between double quotes
    matches = re.findall(r'":\s*"([^"]+)"', value)
    
    # List of words to remove from each match
    words_to_remove = [" Language", " language", " languages", " Languages","\\u00e0 "]
    
    # Remove unwanted words from each match
    if matches:
        for word in words_to_remove:
            matches = [match.replace(word, "") for match in matches]
        return ', '.join(matches)
    
    return value

def remove_unicode_escapes(value):
    # Remove any Unicode escape sequences like \uXXXX
    return re.sub(r'\\u[0-9a-fA-F]{4}', '', value)

    
df_treated['Movie languages'] = df_treated['Movie languages'].apply(cleaner)
df_treated['Movie languages'] = df_treated['Movie languages'].apply(remove_unicode_escapes)

df_treated.head(20)

# %%
df_treated['Movie languages'] = df_treated['Movie languages'].apply(lambda x: x.split(', '))
df_treated.head(20)

# %%
language_list = sum(df_treated['Movie languages'].tolist(), [])

#print(language_list)

# %%
language_counts = pd.Series(language_list).value_counts()

# Plotting the value counts
plt.figure(figsize=(10, 6))
language_counts[:20].plot(kind='bar')
plt.xlabel("Language")
plt.ylabel("Frequency")
plt.title("Frequency of Languages in Movie Data")
plt.xticks(rotation=45)
plt.show()
#empty list is like NaN

# %%
language_counts.to_string()

# %% [markdown]
# ## Genres

# %%
df_treated['Movie genres'] = df_treated['Movie genres'].apply(cleaner)

# %%
df_treated['Movie genres'] = df_treated['Movie genres'].apply(lambda x: x.split(', '))
df_treated.head(20)
# Out:
#                    Movie release date  Movie release month  \
# Wikipedia movie ID
# 975900                     2001-08-24                    8
# 3196793                    2000-02-16                    2
# 28463795                          NaT                 <NA>
# 9363483                           NaT                 <NA>
# 261236                            NaT                 <NA>
# 13696889                   1913-05-29                    5
# 18998739                          NaT                 <NA>
# 10408933                   1938-08-16                    8
# 9997961                           NaT                 <NA>
# 2345652                           NaT                 <NA>
# 175026                            NaT                 <NA>
# 24229100                          NaT                 <NA>
# 6631279                    1997-04-04                    4
# 171005                     1989-11-08                   11
# 18296435                          NaT                 <NA>
# 30388930                          NaT                 <NA>
# 77856                      1964-08-27                    8
# 32456683                          NaT                 <NA>
# 33420460                          NaT                 <NA>
# 175024                            NaT                 <NA>
#
#                     Movie release year  Movie box office revenue  \
# Wikipedia movie ID
# 975900                            2001              2.477118e+07
# 3196793                           2000                       NaN
# 28463795                          1988                       NaN
# 9363483                           1987                       NaN
# 261236                            1983                       NaN
# 13696889                          1913                       NaN
# 18998739                          2002                       NaN
# 10408933                          1938              7.619573e+07
# 9997961                           1974                       NaN
# 2345652                           1960                       NaN
# 175026                            1930                       NaN
# 24229100                          1974                       NaN
# 6631279                           1997                       NaN
# 171005                            1989              2.614955e+07
# 18296435                          1986                       NaN
# 30388930                          1984                       NaN
# 77856                             1964              1.016281e+09
# 32456683                          1967                       NaN
# 33420460                          1992                       NaN
# 175024                            1930                       NaN
#
#                     Movie runtime         Movie languages  \
# Wikipedia movie ID
# 975900                       98.0               [English]
# 3196793                      95.0               [English]
# 28463795                     83.0             [Norwegian]
# 9363483                     110.0               [English]
# 261236                      106.0                [German]
# 13696889                     35.0  [Silent film, English]
# 18998739                     86.0               [English]
# 10408933                    106.0               [English]
# 9997961                       NaN               [Spanish]
# 2345652                      76.0               [English]
# 175026                       86.0               [English]
# 24229100                     89.0              [Japanese]
# 6631279                      93.0               [English]
# 171005                      137.0               [English]
# 18296435                      NaN               [Turkish]
# 30388930                     99.0                      []
# 77856                       139.0               [English]
# 32456683                    108.0                [German]
# 33420460                     97.0               [English]
# 175024                        NaN               [English]
#
#                                                Movie countries  \
# Wikipedia movie ID
# 975900               {"/m/09c7w0": "United States of America"}
# 3196793              {"/m/09c7w0": "United States of America"}
# 28463795                                {"/m/05b4w": "Norway"}
# 9363483                         {"/m/07ssc": "United Kingdom"}
# 261236                                 {"/m/0345h": "Germany"}
# 13696889             {"/m/09c7w0": "United States of America"}
# 18998739                          {"/m/0hzlz": "South Africa"}
# 10408933             {"/m/09c7w0": "United States of America"}
# 9997961                               {"/m/0jgd": "Argentina"}
# 2345652                         {"/m/07ssc": "United Kingdom"}
# 175026               {"/m/09c7w0": "United States of America"}
# 24229100                                 {"/m/03_3d": "Japan"}
# 6631279              {"/m/09c7w0": "United States of America"}
# 171005                          {"/m/07ssc": "United Kingdom"}
# 18296435                               {"/m/01znc_": "Turkey"}
# 30388930                                                    {}
# 77856                {"/m/09c7w0": "United States of America"}
# 32456683            {"/m/03f2w": "German Democratic Republic"}
# 33420460             {"/m/09c7w0": "United States of America"}
# 175024               {"/m/09c7w0": "United States of America"}
#
#                                                          Movie genres
# Wikipedia movie ID
# 975900              [Thriller, Science Fiction, Horror, Adventure,...
# 3196793              [Mystery, Biographical film, Drama, Crime Drama]
# 28463795                                       [Crime Fiction, Drama]
# 9363483             [Thriller, Erotic thriller, Psychological thri...
# 261236                                                        [Drama]
# 13696889            [Short Film, Silent film, Indie, Black-and-whi...
# 18998739              [Family Film, Fantasy, Adventure, World cinema]
# 10408933                           [Musical, Comedy, Black-and-white]
# 9997961                                      [Musical, Drama, Comedy]
# 2345652                                        [Horror, Supernatural]
# 175026                                       [Drama, Black-and-white]
# 24229100            [Crime Fiction, Thriller, Japanese Movies, Wor...
# 6631279             [Romantic comedy, Ensemble Film, Comedy-drama,...
# 171005              [Costume drama, War film, Epic, Period piece, ...
# 18296435                                                     [Comedy]
# 30388930                                                      [Drama]
# 77856               [Children's/Family, Musical, Fantasy, Comedy, ...
# 32456683                                                           []
# 33420460                                                      [Drama]
# 175024                         [Romance Film, Drama, Black-and-white]

# %%
genres_list = sum(df_treated['Movie genres'].tolist(), [])

#print(genres_list)

# %%
genre_counts = pd.Series(genres_list).value_counts()

# Plotting the value counts
plt.figure(figsize=(10, 6))
genre_counts[:20].plot(kind='bar')
plt.xlabel("Genre")
plt.ylabel("Frequency")
plt.title("Frequency of Genres in Movie Data")
plt.xticks(rotation=45)
plt.show()

# %%
genre_counts.to_string()
# Out:
# "Drama                                       32014\nComedy                                      15648\nRomance Film                                 9770\nBlack-and-white                              8817\nThriller                                     8407\nAction                                       8275\nShort Film                                   7208\nWorld cinema                                 7155\nIndie                                        6779\nCrime Fiction                                6624\nSilent film                                  5056\nDocumentary                                  4998\nHorror                                       4982\nAdventure                                    4732\nAction/Adventure                             4557\nFamily Film                                  4165\nMusical                                      3984\nComedy film                                  3717\nRomantic drama                               3345\nMystery                                      3055\nAnimation                                    3034\nScience Fiction                              2888\nFantasy                                      2655\nRomantic comedy                              2633\nWar film                                     2536\nWestern                                      2170\nCrime Thriller                               2109\nJapanese Movies                              2087\n                                             1762\nPeriod piece                                 1743\nComedy-drama                                 1679\nFilm adaptation                              1529\nChinese Movies                               1373\nBiography                                    1362\nBollywood                                    1316\nPsychological thriller                       1314\nLGBT                                         1146\nSports                                       1139\nBiographical film                            1099\nFamily Drama                                 1027\nBlack comedy                                 1018\nMusic                                        1005\nParody                                        992\nTelevision movie                              968\nTeen                                          918\nComing of age                                 896\nMartial Arts Film                             892\nChildren's/Family                             889\nHistory                                       864\nPolitical drama                               782\nCult                                          759\nSlasher                                       756\nSuspense                                      755\nCulture & Society                             710\nMelodrama                                     701\nSatire                                        694\nSupernatural                                  637\nBiopic [feature]                              620\nFilm noir                                     612\nSlapstick                                     606\nHistorical fiction                            556\nCrime Drama                                   552\nAction Thrillers                              503\nChildren's                                    494\nB-movie                                       493\nCostume drama                                 481\nSpy                                           465\nArt film                                      461\nEnsemble Film                                 447\nGangster Film                                 425\nAnime                                         416\nPolitical cinema                              415\nDocudrama                                     400\nDetective                                     395\nCreature Film                                 382\nBuddy film                                    369\nGay Themed                                    353\nRoad movie                                    337\nDetective fiction     ...

# %% [markdown]
# ## Countries

# %%
df_treated['Movie countries'] = df_treated['Movie countries'].apply(cleaner)

# %%
df_treated['Movie countries'] = df_treated['Movie countries'].apply(lambda x: x.split(', '))
df_treated.head(20)
# Out:
#                    Movie release date  Movie release month  \
# Wikipedia movie ID
# 975900                     2001-08-24                    8
# 3196793                    2000-02-16                    2
# 28463795                          NaT                 <NA>
# 9363483                           NaT                 <NA>
# 261236                            NaT                 <NA>
# 13696889                   1913-05-29                    5
# 18998739                          NaT                 <NA>
# 10408933                   1938-08-16                    8
# 9997961                           NaT                 <NA>
# 2345652                           NaT                 <NA>
# 175026                            NaT                 <NA>
# 24229100                          NaT                 <NA>
# 6631279                    1997-04-04                    4
# 171005                     1989-11-08                   11
# 18296435                          NaT                 <NA>
# 30388930                          NaT                 <NA>
# 77856                      1964-08-27                    8
# 32456683                          NaT                 <NA>
# 33420460                          NaT                 <NA>
# 175024                            NaT                 <NA>
#
#                     Movie release year  Movie box office revenue  \
# Wikipedia movie ID
# 975900                            2001              2.477118e+07
# 3196793                           2000                       NaN
# 28463795                          1988                       NaN
# 9363483                           1987                       NaN
# 261236                            1983                       NaN
# 13696889                          1913                       NaN
# 18998739                          2002                       NaN
# 10408933                          1938              7.619573e+07
# 9997961                           1974                       NaN
# 2345652                           1960                       NaN
# 175026                            1930                       NaN
# 24229100                          1974                       NaN
# 6631279                           1997                       NaN
# 171005                            1989              2.614955e+07
# 18296435                          1986                       NaN
# 30388930                          1984                       NaN
# 77856                             1964              1.016281e+09
# 32456683                          1967                       NaN
# 33420460                          1992                       NaN
# 175024                            1930                       NaN
#
#                     Movie runtime         Movie languages  \
# Wikipedia movie ID
# 975900                       98.0               [English]
# 3196793                      95.0               [English]
# 28463795                     83.0             [Norwegian]
# 9363483                     110.0               [English]
# 261236                      106.0                [German]
# 13696889                     35.0  [Silent film, English]
# 18998739                     86.0               [English]
# 10408933                    106.0               [English]
# 9997961                       NaN               [Spanish]
# 2345652                      76.0               [English]
# 175026                       86.0               [English]
# 24229100                     89.0              [Japanese]
# 6631279                      93.0               [English]
# 171005                      137.0               [English]
# 18296435                      NaN               [Turkish]
# 30388930                     99.0                      []
# 77856                       139.0               [English]
# 32456683                    108.0                [German]
# 33420460                     97.0               [English]
# 175024                        NaN               [English]
#
#                                  Movie countries  \
# Wikipedia movie ID
# 975900                [United States of America]
# 3196793               [United States of America]
# 28463795                                [Norway]
# 9363483                         [United Kingdom]
# 261236                                 [Germany]
# 13696889              [United States of America]
# 18998739                          [South Africa]
# 10408933              [United States of America]
# 9997961                              [Argentina]
# 2345652                         [United Kingdom]
# 175026                [United States of America]
# 24229100                                 [Japan]
# 6631279               [United States of America]
# 171005                          [United Kingdom]
# 18296435                                [Turkey]
# 30388930                                      []
# 77856                 [United States of America]
# 32456683            [German Democratic Republic]
# 33420460              [United States of America]
# 175024                [United States of America]
#
#                                                          Movie genres
# Wikipedia movie ID
# 975900              [Thriller, Science Fiction, Horror, Adventure,...
# 3196793              [Mystery, Biographical film, Drama, Crime Drama]
# 28463795                                       [Crime Fiction, Drama]
# 9363483             [Thriller, Erotic thriller, Psychological thri...
# 261236                                                        [Drama]
# 13696889            [Short Film, Silent film, Indie, Black-and-whi...
# 18998739              [Family Film, Fantasy, Adventure, World cinema]
# 10408933                           [Musical, Comedy, Black-and-white]
# 9997961                                      [Musical, Drama, Comedy]
# 2345652                                        [Horror, Supernatural]
# 175026                                       [Drama, Black-and-white]
# 24229100            [Crime Fiction, Thriller, Japanese Movies, Wor...
# 6631279             [Romantic comedy, Ensemble Film, Comedy-drama,...
# 171005              [Costume drama, War film, Epic, Period piece, ...
# 18296435                                                     [Comedy]
# 30388930                                                      [Drama]
# 77856               [Children's/Family, Musical, Fantasy, Comedy, ...
# 32456683                                                           []
# 33420460                                                      [Drama]
# 175024                         [Romance Film, Drama, Black-and-white]

# %%
countries_list = sum(df_treated['Movie countries'].tolist(), [])

#print(countries_list)

# %%
country_counts = pd.Series(countries_list).value_counts()

# Plotting the value counts
plt.figure(figsize=(10, 6))
country_counts[:20].plot(kind='bar')
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.title("Frequency of Countries in Movie Data")
plt.xticks(rotation=45)
plt.show()
#empty is nan

# %%
country_counts.to_string()
# Out:
# 'United States of America                    33197\nIndia                                        7764\nUnited Kingdom                               7452\n                                             5228\nFrance                                       4199\nItaly                                        3017\nJapan                                        2405\nCanada                                       2372\nGermany                                      2306\nArgentina                                    1418\nHong Kong                                    1115\nSpain                                        1045\nAustralia                                    1038\nSouth Korea                                   861\nMexico                                        844\nNetherlands                                   820\nSweden                                        629\nWest Germany                                  623\nChina                                         611\nDenmark                                       596\nSoviet Union                                  522\nPhilippines                                   374\nCzechoslovakia                                367\nPoland                                        362\nBelgium                                       347\nNew Zealand                                   339\nRussia                                        326\nNorway                                        320\nHungary                                       314\nGerman Democratic Republic                    310\nYugoslavia                                    299\nBrazil                                        277\nIreland                                       274\nSwitzerland                                   268\nAustria                                       257\nCzech Republic                                235\nFinland                                       230\nIsrael                                        214\nEngland                                       211\nTurkey                                        206\nSouth Africa                                  190\nThailand                                      169\nGreece                                        169\nTaiwan                                        168\nIran                                          161\nPakistan                                      158\nPortugal                                      157\nCroatia                                       150\nEgypt                                         133\nRomania                                       130\nIndonesia                                     114\nBulgaria                                       97\nMalaysia                                       91\nSri Lanka                                      81\nSingapore                                      77\nIceland                                        74\nLuxembourg                                     72\nWeimar Republic                                67\nCambodia                                       63\nBangladesh                                     62\nChile                                          57\nMorocco                                        54\nSerbia                                         52\nColombia                                       49\nCuba                                           44\nAlgeria                                        43\nScotland                                       42\nTunisia                                        40\nLebanon                                        36\nEstonia                                        34\nBosnia and Herzegovina                         34\nNepal                                          33\nSlovakia                                       31\nSenegal                                        31\nPuerto Rico                                    30\nBurkina Faso                                   30\nSlovenia                                       29\nVenezuela                                      29\nVietnam               ...

# %%
df_treated.to_csv('cleaned_data.csv', index=True)

# %%
df_treated.head(100).to_csv('test_export.csv', index=True)

# %%
df_treated.to_csv('cleaned_data.csv', index=True, encoding='utf-8')
