# %% [markdown]
# # 1. IMPORTS

# %% [markdown]
# ## 1.1 Libraries

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# ## 1.2 Data

# %%
folder = "../temporary/"

df_events=pd.read_csv(folder + "usa_historical_events.csv")
df_treated=pd.read_csv(folder + "cleaned_data.csv",index_col = 'Wikipedia movie ID')

PLOT_SUMMARIES = "../data/plot_summaries.txt"

with open(PLOT_SUMMARIES, 'r', encoding='utf-8') as file:
    plot_summaries = file.readlines()

# %% [markdown]
# # 2. PLOT TONE SCORE

# %%
# For this, we use the "VADER sentiment analysis" library which contains a dictionary. Each of the words inside are associated to a polarity score depending on how positive or negative they are. One total 
#score is computed per summary, and then it is normalized and takes a value between -1 and +1 to categorize the text as positive, negative or neutral. 

analyzer = SentimentIntensityAnalyzer()

def get_sentiment(text):
    score = analyzer.polarity_scores(text)
    compound_score = score['compound']
    if compound_score >= 0.1:
        sentiment = 'positive'
    elif compound_score <= -0.1:
        sentiment = 'negative'
    else:
        sentiment = 'neutral'
    return sentiment, compound_score

# %%
data = []

for line in plot_summaries:
    parts = line.strip().split('\t', 1) # Split each line by the tab character
    if len(parts) == 2:
        movie_id, summary = parts
        sentiment, compound_score = get_sentiment(summary)
        data.append([movie_id, summary, sentiment, compound_score])

df_sent = pd.DataFrame(data, columns=['ID', 'Summary', 'Sentiment', 'Compound Score'])
df_sent = df_sent.set_index('ID')

df_sent.head(10)
# Out:
#                                                     Summary Sentiment  \
# ID
# 23890098  Shlykov, a hard-working taxi driver and Lyosha...   neutral
# 31186339  The nation of Panem consists of a wealthy Capi...  negative
# 20663735  Poovalli Induchoodan  is sentenced for six yea...  negative
# 2231378   The Lemon Drop Kid , a New York City swindler,...  negative
# 595909    Seventh-day Adventist Church pastor Michael Ch...  negative
# 5272176   The president is on his way to give a speech. ...  negative
# 1952976   {{plot}} The film opens in 1974, as a young gi...  negative
# 24225279  The story begins with Hannah, a young Jewish t...  negative
# 2462689   Infuriated at being told to write one final co...  negative
# 20532852  A line of people  drool at the window of the s...  negative
#
#           Compound Score
# ID
# 23890098          0.0083
# 31186339         -0.9941
# 20663735         -0.9867
# 2231378          -0.6127
# 595909           -0.9538
# 5272176          -0.9946
# 1952976          -0.7904
# 24225279         -0.5064
# 2462689          -0.9898
# 20532852         -0.8176

# %%
df_sent.index = df_sent.index.astype('int64')
df_merged = pd.merge(df_treated, df_sent, left_index=True, right_index=True, how='left')

# %%
df_events[['Sentiment', 'Compound Score']] = df_events.apply(
    lambda row: pd.Series(get_sentiment(row['Description'])) if pd.notna(row['Description']) else pd.Series(get_sentiment(row['Title'])),
    axis=1)

# %%
df_merged.head(10)
# Out:
#                                                            Movie name  \
# Wikipedia movie ID
# 975900                                                 Ghosts of Mars
# 3196793             Getting Away with Murder: The JonBenét Ramsey ...
# 28463795                                                  Brun bitter
# 9363483                                              White Of The Eye
# 261236                                              A Woman in Flames
# 13696889                                                The Gangsters
# 18998739                                    The Sorcerer's Apprentice
# 10408933                                     Alexander's Ragtime Band
# 9997961                                                Contigo y aquí
# 2345652                                              City of the Dead
#
#                     Movie release month  Movie release year  \
# Wikipedia movie ID
# 975900                              8.0              2001.0
# 3196793                             2.0              2000.0
# 28463795                            NaN              1988.0
# 9363483                             NaN              1987.0
# 261236                              NaN              1983.0
# 13696889                            5.0              1913.0
# 18998739                            NaN              2002.0
# 10408933                            8.0              1938.0
# 9997961                             NaN              1974.0
# 2345652                             NaN              1960.0
#
#                    Movie release date  Movie box office revenue  \
# Wikipedia movie ID
# 975900                     2001-08-24              2.477118e+07
# 3196793                    2000-02-16                       NaN
# 28463795                          NaN                       NaN
# 9363483                           NaN                       NaN
# 261236                            NaN                       NaN
# 13696889                   1913-05-29                       NaN
# 18998739                          NaN                       NaN
# 10408933                   1938-08-16              7.619573e+07
# 9997961                           NaN                       NaN
# 2345652                           NaN                       NaN
#
#                     Movie runtime             Movie languages  \
# Wikipedia movie ID
# 975900                       98.0                 ['English']
# 3196793                      95.0                 ['English']
# 28463795                     83.0               ['Norwegian']
# 9363483                     110.0                 ['English']
# 261236                      106.0                  ['German']
# 13696889                     35.0  ['Silent film', 'English']
# 18998739                     86.0                 ['English']
# 10408933                    106.0                 ['English']
# 9997961                       NaN                 ['Spanish']
# 2345652                      76.0                 ['English']
#
#                                  Movie countries  \
# Wikipedia movie ID
# 975900              ['United States of America']
# 3196793             ['United States of America']
# 28463795                              ['Norway']
# 9363483                       ['United Kingdom']
# 261236                               ['Germany']
# 13696889            ['United States of America']
# 18998739                        ['South Africa']
# 10408933            ['United States of America']
# 9997961                            ['Argentina']
# 2345652                       ['United Kingdom']
#
#                                                          Movie genres  \
# Wikipedia movie ID
# 975900              ['Thriller', 'Science Fiction', 'Horror', 'Adv...
# 3196793             ['Mystery', 'Biographical film', 'Drama', 'Cri...
# 28463795                                   ['Crime Fiction', 'Drama']
# 9363483             ['Thriller', 'Erotic thriller', 'Psychological...
# 261236                                                      ['Drama']
# 13696889            ['Short Film', 'Silent film', 'Indie', 'Black-...
# 18998739            ['Family Film', 'Fantasy', 'Adventure', 'World...
# 10408933                     ['Musical', 'Comedy', 'Black-and-white']
# 9997961                                ['Musical', 'Drama', 'Comedy']
# 2345652                                    ['Horror', 'Supernatural']
#
#                                                               Summary  \
# Wikipedia movie ID
# 975900              Set in the second half of the 22nd century, th...
# 3196793                                                           NaN
# 28463795                                                          NaN
# 9363483             A series of murders of rich young women throug...
# 261236              Eva, an upper class housewife, becomes frustra...
# 13696889                                                          NaN
# 18998739            Every hundred years, the evil Morgana  returns...
# 10408933                                                          NaN
# 9997961                                                           NaN
# 2345652                                                           NaN
#
#                    Sentiment  Compound Score
# Wikipedia movie ID
# 975900              negative         -0.9913
# 3196793                  NaN             NaN
# 28463795                 NaN             NaN
# 9363483             negative         -0.9983
# 261236              positive          0.9604
# 13696889                 NaN             NaN
# 18998739            negative         -0.8885
# 10408933                 NaN             NaN
# 9997961                  NaN             NaN
# 2345652                  NaN             NaN

# %%
df_events.head(10)
# Out:
#          Date                                         Title  \
# 0  1900-03-14                      Gold Standard Act passed
# 1  1900-11-06                  McKinley reelected president
# 2  1901-02-25               Congress passes Platt Amendment
# 3  1901-02-25  J.P. Morgan creates United States Steel Corp
# 4  1901-07-29               American Socialist Party formed
# 5  1901-09-06   McKinley assassinated; TR becomes president
# 6  1902-10-03       TR intervenes in anthracite coal strike
# 7  1903-01-01                           Souls of Black Folk
# 8  1903-11-19             Women's Trade Union League Formed
# 9  1903-12-17       Wright Bros. make 1st successful flight
#
#                                          Description Sentiment  Compound Score
# 0  Established gold as the only standard for rede...  positive          0.8934
# 1                                                NaN   neutral          0.0000
# 2  The Platt Amendment, an amendment to a U.S. ar...  positive          0.3818
# 3  1 of the most powerful bankers of his era, he ...  negative         -0.1796
# 4  a multi-tendency democratic-socialist politica...  positive          0.9231
# 5  Pres McKinley is shot at the Pan American Expo...  negative         -0.9382
# 6  The strike of 1900 was the prelude to a larger...  negative         -0.1010
# 7  W. E. B. Du Bois’s landmark book of essays, So...  positive          0.4767
# 8  a U.S. org of both working class & more well-o...  positive          0.7430
# 9  Orville Wright piloted the first powered airpl...   neutral          0.0000

# %% [markdown]
# # 3. EXPORT CLEAN DATASETS

# %%
df_merged.to_csv('../generated/cleaned_data.csv', index=True, encoding='utf-8')

# %%
df_events.to_csv('../generated/usa_historical_events.csv',index = False)
