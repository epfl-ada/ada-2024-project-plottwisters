# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup 
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import plotly.express as px
import openai
import os
import time

# %%
openai.api_key ="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"

def chatgpt(message):
    #time.sleep(0.1)
    completion = openai.chat.completions.create(model="gpt-4o-mini",messages=[{"role": "user","content": message,},],)
    print(completion.choices[0].message.content)
    return completion.choices[0].message.content

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4o-mini")

with open("data/plot_summaries.txt", "r",encoding="utf-8") as file:
    text = file.read()

tokens = encoding.encode(text)
num_tokens = len(tokens)

print(f"Number of tokens in the document: {num_tokens}")
# Out:
# Number of tokens in the document: 16544268

# %%
price_dataset = (0.15*16544268)/1000000
price_dataset
# Out:
# 2.4816401999999997

# %%
folder = "generated/"
df_movies=pd.read_csv(folder + "cleaned_data.csv",index_col = 'Wikipedia movie ID')
df_movies.head(10)
# Out:
#                                                            Movie name  \
# Wikipedia movie ID
# 975900                                                 Ghosts of Mars
# 3196793             Getting Away with Murder: The JonBenét Ramsey ...
# 28463795                                                  Brun bitter
# 9363483                                              White Of The Eye
# 261236                                              A Woman in Flames
# 13696889                                                The Gangsters
# 18998739                                    The Sorcerer's Apprentice
# 10408933                                     Alexander's Ragtime Band
# 9997961                                                Contigo y aquí
# 2345652                                              City of the Dead
#
#                     Movie release month  Movie release year  \
# Wikipedia movie ID
# 975900                              8.0              2001.0
# ...

# %%
dfs = np.array_split(df_movies, 10)

df1, df2, df3, df4, df5, df6, df7, df8, df9, df10 = dfs
# Out:
# C:\Users\nicol\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
pre = "Label the movie's theme with a single word based on its plot : "
df1['Theme'] = df1['Summary'].apply(lambda x: chatgpt(pre + x) if pd.notna(x) else np.nan)
# Out:
# Possession
# **Destruction**
# Empowerment
# Destiny
# Heartbreak
# Unity
# Identity
# **Heroism**
# **Nostalgia**
# Revolution
# Rediscovery
# **Dreams**
# **Maturity**
# Deception
# **Redemption**
# **Love**
# **Mortality**
# Redemption
# Redemption
# Reunion
# Parody
# Jealousy
# **Theme:** Conflict
# **Escape**
# **Revenge**
# Resilience
# "Rebellion"
# Transformation
# Puppetship
# Nostalgia
# Redemption
# Rebellion
# Desire
# Revenge
# Separation
# Rebellion
# **Redemption**
# Desire
# Justice
# Racism
# Conflict
# Infidelity
# **Love**
# Intrigue
# **Survival**
# **Espionage**
# "Guilt"
# Loss
# Resilience
# Loss
# Forbidden
# "Paranoia"
# Sacrifice
# Ecology
# Greed
# Revenge
# Survival
# Friendship
# Sacrifice
# Chaos
# Justice
# Revolution
# "Desire"
# Ambition.
# Hybrid
# Reconnaissance
# Obsession
# Thematic Word: Rivalry
# Justice
# **Redemption**
# **Love**
# "Rebellion"
# **Disillusionment**
# **Adventure**
# **Love**
# Imagination
# **Corruption**
# Oppression
# ...

# %%
df1['Theme'] = df1['Theme'].astype('object')

df1.to_csv('df1_temporary.csv')

# %%
df1.head(10)

# %%
#df['column_with_chars'] = df['column_with_chars'].str.replace(r'["*]', '', regex=True)

#df = df[~df['column_with_chars'].str.startswith('theme:')]
